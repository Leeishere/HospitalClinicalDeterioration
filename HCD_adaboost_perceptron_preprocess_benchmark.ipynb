# %% [markdown]
# # AdaBoost (Perceptron Base Estimator) Preprocessing Benchmark

# %%
from preprocessing_benchmark_framework import (
    print_best_model_metrics,
    run_preprocessing_benchmark,
)

results_df, strategy_artifacts, top_per_metric, top_scores_df, top_combined, _ = run_preprocessing_benchmark(
    model_type='adaboost',
    variant='perceptron',
    output_dir_name='adaboost_perceptron',
    run_randomized=True,
    run_explicit=False,
    n_random_iterations_override=2,
    use_imbalance_options=False,
    balance_classes_before_training=True,
    total_threads=16,
    num_current_notebooks=4,
    iqr_multiplier=3.0,
    numeric_transformer_names=['standard_scaler'],
    add_polynomial=True,
    score_priority=['recall', 'precision', 'accuracy', 'f1', 'ROC-AUC'],
    top_n=25,
    metrics_to_save=[],
)

# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_columns", None)   # show all columns
pd.set_option("display.max_colwidth", None) # show full column content

priority = ['recall', 'precision', 'accuracy', 'f1', 'roc_auc']

print_best_model_metrics(results_df, metrics_to_show=priority)

print('Top score per metric (top-1 by metric):')
display(top_scores_df)

print('Combined top-N shortlist (deduplicated, sorted by ROC-AUC):')
display(top_combined)
# Out:
# Best model by test_recall:
# config=num=log_transformer, cat=ordinalencoder, outliers=False, squared=True, cubed=False
# best_params={'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# dataset  recall  precision  accuracy    f1  roc_auc
#   train   0.945      0.150     0.681 0.259    0.895
#    test   0.945      0.151     0.683 0.260    0.895
#
# Best model by test_precision:
# config=num=sqrt_transformer, cat=ordinalencoder, outliers=True, squared=True, cubed=False
# best_params={'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# dataset  recall  precision  accuracy    f1  roc_auc
#   train   0.611      0.685      0.96 0.646    0.826
#    test   0.610      0.680      0.96 0.643    0.825
#
# Best model by test_accuracy:
# config=num=sqrt_transformer, cat=ordinalencoder, outliers=True, squared=True, cubed=False
# best_params={'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# dataset  recall  precision  accuracy    f1  roc_auc
#   train   0.611      0.685      0.96 0.646    0.826
#    test   0.610      0.680      0.96 0.643    0.825
#
# Best model by test_f1:
# config=num=sqrt_transformer, cat=ordinalencoder, outliers=True, squared=True, cubed=False
# best_params={'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# dataset  recall  precision  accuracy    f1  roc_auc
#   train   0.611      0.685      0.96 0.646    0.826
#    test   0.610      0.680      0.96 0.643    0.825
#
# Best model by test_roc_auc:
# config=num=log_transformer, cat=ordinalencoder, outliers=True, squared=True, cubed=True
# best_params={'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
# dataset  recall  precision  accuracy    f1  roc_auc
#   train   0.821      0.283     0.866 0.421    0.930
#    test   0.821      0.284     0.867 0.422    0.931
# Top score per metric (top-1 by metric):
#       metric   run_id numeric_transformer categorical_transformer  \
# 0     recall  run_028     log_transformer          ordinalencoder
# 1  precision  run_047    sqrt_transformer          ordinalencoder
# 2   accuracy  run_047    sqrt_transformer          ordinalencoder
# 3         f1  run_047    sqrt_transformer          ordinalencoder
# 4    roc_auc  run_051     log_transformer          ordinalencoder
#
#    outliers_clipped  outliers_enabled  use_squared  use_cubed  \
# 0             False             False         True      False
# 1              True              True         True      False
# 2              True              True         True      False
# 3              True              True         True      False
# 4              True              True        False       True
#
#                                                      model_params  \
# 0  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 1  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 2  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 3  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 4  {'learning_rate': 0.5, 'n_estimators': 40, 'random_state': 42}
#
#                                                       best_params  \
# 0  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 1  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 2  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 3  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 4  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
#
#    iqr_multiplier  n_numeric_cols  n_categorical_cols  n_transformed_features  \
# 0             3.0              36                   3                      39
# 1             3.0              36                   3                      39
# 2             3.0              36                   3                      39
# 3             3.0              36                   3                      39
# 4             3.0              36                   3                      39
#
#    train_recall  train_precision  train_accuracy  train_f1  train_roc_auc  \
# 0         0.945            0.150           0.681     0.259          0.895
# 1         0.611            0.685           0.960     0.646          0.826
# 2         0.611            0.685           0.960     0.646          0.826
# 3         0.611            0.685           0.960     0.646          0.826
# 4         0.825            0.288           0.869     0.427          0.930
#
#    test_recall  test_precision  test_accuracy  test_f1  test_roc_auc  \
# 0        0.945           0.151          0.683    0.260         0.895
# 1        0.610           0.680          0.960    0.643         0.825
# 2        0.610           0.680          0.960    0.643         0.825
# 3        0.610           0.680          0.960    0.643         0.825
# 4        0.831           0.291          0.871    0.432         0.931
#
#    joined_recall  joined_precision  joined_accuracy  joined_f1  joined_roc_auc
# 0          0.944             0.121            0.625      0.214           0.821
# 1          0.612             0.252            0.881      0.357           0.781
# 2          0.612             0.252            0.881      0.357           0.781
# 3          0.612             0.252            0.881      0.357           0.781
# 4          0.824             0.188            0.797      0.306           0.861
# Combined top-N shortlist (deduplicated, sorted by ROC-AUC):
#      run_id numeric_transformer categorical_transformer  outliers_clipped  \
# 0   run_051     log_transformer          ordinalencoder              True
# 1   run_075     log_transformer          ordinalencoder              True
# 2   run_026     log_transformer           onehotencoder             False
# 3   run_023    sqrt_transformer          ordinalencoder              True
# 4   run_015       robust_scaler          ordinalencoder              True
# ..      ...                 ...                     ...               ...
# 61  run_019  custom_transformer          ordinalencoder              True
# 62  run_017  custom_transformer           onehotencoder              True
# 63  run_047    sqrt_transformer          ordinalencoder              True
# 64  run_041  custom_transformer           onehotencoder              True
# 65  run_044  custom_transformer          ordinalencoder             False
#
#     outliers_enabled  use_squared  use_cubed  \
# 0               True        False       True
# 1               True         True       True
# 2              False         True      False
# 3               True        False      False
# 4               True        False      False
# ..               ...          ...        ...
# 61              True        False      False
# 62              True        False      False
# 63              True         True      False
# 64              True         True      False
# 65             False         True      False
#
#                                                       model_params  \
# 0   {'learning_rate': 0.5, 'n_estimators': 40, 'random_state': 42}
# 1   {'learning_rate': 0.5, 'n_estimators': 40, 'random_state': 42}
# 2   {'learning_rate': 0.5, 'n_estimators': 40, 'random_state': 42}
# 3   {'learning_rate': 0.5, 'n_estimators': 40, 'random_state': 42}
# 4   {'learning_rate': 0.5, 'n_estimators': 40, 'random_state': 42}
# ..                                                             ...
# 61  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 62  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 63  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 64  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
# 65  {'learning_rate': 1.0, 'n_estimators': 40, 'random_state': 42}
#
#                                                        best_params  \
# 0   {'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
# 1   {'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
# 2   {'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
# 3   {'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
# 4   {'random_state': 42, 'n_estimators': 40, 'learning_rate': 0.5}
# ..                                                             ...
# 61  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 62  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 63  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 64  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
# 65  {'random_state': 42, 'n_estimators': 40, 'learning_rate': 1.0}
#
#     iqr_multiplier  n_numeric_cols  n_categorical_cols  \
# 0              3.0              36                   3
# 1              3.0              54                   3
# 2              3.0              36                   3
# 3              3.0              18                   3
# 4              3.0              18                   3
# ..             ...             ...                 ...
# 61             3.0              18                   3
# 62             3.0              18                   3
# 63             3.0              36                   3
# 64             3.0              36                   3
# 65             3.0              36                   3
#
#     n_transformed_features  train_recall  train_precision  train_accuracy  \
# 0                       39         0.825            0.288           0.869
# 1                       57         0.821            0.283           0.866
# 2                       43         0.848            0.255           0.845
# 3                       21         0.855            0.249           0.839
# 4                       21         0.810            0.315           0.885
# ..                     ...           ...              ...             ...
# 61                      21         0.588            0.498           0.941
# 62                      25         0.875            0.163           0.728
# 63                      39         0.611            0.685           0.960
# 64                      43         0.695            0.368           0.912
# 65                      39         0.679            0.404           0.922
#
#     train_f1  train_roc_auc  test_recall  test_precision  test_accuracy  \
# 0      0.427          0.930        0.831           0.291          0.871
# 1      0.421          0.930        0.821           0.284          0.867
# 2      0.393          0.928        0.853           0.258          0.846
# 3      0.385          0.930        0.851           0.249          0.839
# 4      0.454          0.929        0.812           0.320          0.887
# ..       ...            ...          ...             ...            ...
# 61     0.539          0.831        0.595           0.504          0.942
# 62     0.275          0.828        0.879           0.164          0.728
# 63     0.646          0.826        0.610           0.680          0.960
# 64     0.482          0.810        0.701           0.372          0.912
# 65     0.507          0.808        0.687           0.408          0.923
#
#     test_f1  test_roc_auc  joined_recall  joined_precision  joined_accuracy  \
# 0     0.432         0.931          0.824             0.188            0.797
# 1     0.422         0.931          0.828             0.187            0.796
# 2     0.396         0.930          0.849             0.175            0.775
# 3     0.385         0.930          0.855             0.171            0.769
# 4     0.459         0.929          0.809             0.197            0.811
# ..      ...           ...            ...               ...              ...
# 61    0.546         0.837          0.587             0.217            0.864
# 62    0.277         0.831          0.872             0.127            0.669
# 63    0.643         0.825          0.612             0.252            0.881
# 64    0.486         0.813          0.694             0.204            0.837
# 65    0.512         0.812          0.680             0.212            0.846
#
#     joined_f1  joined_roc_auc
# 0       0.306           0.861
# 1       0.305           0.854
# 2       0.290           0.852
# 3       0.285           0.860
# 4       0.316           0.853
# ..        ...             ...
# 61      0.317           0.780
# 62      0.221           0.766
# 63      0.357           0.781
# 64      0.315           0.769
# 65      0.323           0.768
#
# [66 rows x 28 columns]
